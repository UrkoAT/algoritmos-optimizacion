# %% [markdown]
# <a href="https://colab.research.google.com/github/UrkoAT/algoritmos-optimizacion/blob/main/Urko_Agirregomezkorta_AG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad Guiada 1 de Algoritmos de Optimizacion
#
# Nombre: Urko Agirregomezkorta Txurruka
#
# https://github.com/UrkoAT/algoritmos-optimizacion

# %%
#Torres de Hanoi - Divide y venceras
################################################################################


################################################################
def Torres_Hanoi(N, desde, hasta):
  #N - Nº de fichas
  #desde - torre inicial
  #hasta - torre fina
  if N==1 :
    print("Lleva la ficha desde " + str(desde) + " hasta " + str(hasta))

  else:
    Torres_Hanoi(N-1, desde, 6-desde-hasta)
    print("Lleva la ficha desde " + str(desde) + " hasta " + str(hasta))
    Torres_Hanoi(N-1, 6-desde-hasta,  hasta)

Torres_Hanoi(12, 1, 3)
################################################################
# Out:
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 3 hasta 2
# ...

# %%
#Cambio de monedas - Técnica voraz
################################################################################
SISTEMA = [20 , 10, 5, 2, 1  ]
################################################################
def cambio_monedas(CANTIDAD,SISTEMA):
#....
  SOLUCION = [0]*len(SISTEMA)
  ValorAcumulado = 0

  for i,valor in enumerate(SISTEMA):
    monedas = (CANTIDAD-ValorAcumulado)//valor
    SOLUCION[i] = monedas
    ValorAcumulado = ValorAcumulado + monedas*valor

    if CANTIDAD == ValorAcumulado:
      return SOLUCION

  print("No es posible encontrar solucion")

cambio_monedas(124,SISTEMA)


################################################################
# Out:
# [6, 0, 0, 2, 0]

# %%
#N Reinas - Vuelta Atrás()
################################################################################

#Verifica que en la solución parcial no hay amenzas entre reinas
################################################################
def es_prometedora(SOLUCION,etapa):
################################################################
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:
      return False

    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True

#Traduce la solución al tablero
################################################################
def escribe_solucion(S):
################################################################
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")



#Proceso principal de N-Reinas
################################################################
def reinas(N, solucion=[],etapa=0):
################################################################
### ....
  if len(solucion) == 0:         # [0,0,0...]
    solucion = [0 for i in range(N) ]

  for i in range(1, N+1):
    solucion[etapa] = i
    if es_prometedora(solucion, etapa):
      if etapa == N-1:
        print(solucion)
      else:
        reinas(N, solucion, etapa+1)
    else:
      None

  solucion[etapa] = 0

reinas(8,solucion=[],etapa=0)
# Out:
# [1, 5, 8, 6, 3, 7, 2, 4]
# [1, 6, 8, 3, 7, 4, 2, 5]
# [1, 7, 4, 6, 8, 2, 5, 3]
# [1, 7, 5, 8, 2, 4, 6, 3]
# [2, 4, 6, 8, 3, 1, 7, 5]
# [2, 5, 7, 1, 3, 8, 6, 4]
# [2, 5, 7, 4, 1, 8, 6, 3]
# [2, 6, 1, 7, 4, 8, 3, 5]
# [2, 6, 8, 3, 1, 4, 7, 5]
# [2, 7, 3, 6, 8, 5, 1, 4]
# [2, 7, 5, 8, 1, 4, 6, 3]
# [2, 8, 6, 1, 3, 5, 7, 4]
# [3, 1, 7, 5, 8, 2, 4, 6]
# [3, 5, 2, 8, 1, 7, 4, 6]
# [3, 5, 2, 8, 6, 4, 7, 1]
# [3, 5, 7, 1, 4, 2, 8, 6]
# [3, 5, 8, 4, 1, 7, 2, 6]
# [3, 6, 2, 5, 8, 1, 7, 4]
# [3, 6, 2, 7, 1, 4, 8, 5]
# [3, 6, 2, 7, 5, 1, 8, 4]
# [3, 6, 4, 1, 8, 5, 7, 2]
# [3, 6, 4, 2, 8, 5, 7, 1]
# [3, 6, 8, 1, 4, 7, 5, 2]
# [3, 6, 8, 1, 5, 7, 2, 4]
# [3, 6, 8, 2, 4, 1, 7, 5]
# [3, 7, 2, 8, 5, 1, 4, 6]
# [3, 7, 2, 8, 6, 4, 1, 5]
# [3, 8, 4, 7, 1, 6, 2, 5]
# [4, 1, 5, 8, 2, 7, 3, 6]
# [4, 1, 5, 8, 6, 3, 7, 2]
# [4, 2, 5, 8, 6, 1, 3, 7]
# [4, 2, 7, 3, 6, 8, 1, 5]
# [4, 2, 7, 3, 6, 8, 5, 1]
# [4, 2, 7, 5, 1, 8, 6, 3]
# [4, 2, 8, 5, 7, 1, 3, 6]
# [4, 2, 8, 6, 1, 3, 5, 7]
# [4, 6, 1, 5, 2, 8, 3, 7]
# ...

# %%
escribe_solucion([8, 4, 1, 3, 6, 2, 7, 5])
# Out:
#  -  -  X  -  -  -  -  -
#  -  -  -  -  -  X  -  -
#  -  -  -  X  -  -  -  -
#  -  X  -  -  -  -  -  -
#  -  -  -  -  -  -  -  X
#  -  -  -  -  X  -  -  -
#  -  -  -  -  -  -  X  -
#  X  -  -  -  -  -  -  -

# %%
#Viaje por el rio - Programación dinámica
################################################################################

TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

#999 se puede sustituir por float("inf")


#Calculo de la matriz de PRECIOS y RUTAS
################################################################
def Precios(TARIFAS):
################################################################
  #Total de Nodos
  N = len(TARIFAS[0])

  #Inicialización de la tabla de precios
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]

  for i in range(0,N-1):
    RUTA[i][i] = i             #Para ir de i a i se "pasa por i"
    PRECIOS[i][i] = 0          #Para ir de i a i se se paga 0
    for j in range(i+1, N):
      MIN = TARIFAS[i][j]
      RUTA[i][j] = i

      for k in range(i, j):
        if PRECIOS[i][k] + TARIFAS[k][j] < MIN:
            MIN = min(MIN, PRECIOS[i][k] + TARIFAS[k][j] )
            RUTA[i][j] = k          #Anota que para ir de i a j hay que pasar por k
        PRECIOS[i][j] = MIN

  return PRECIOS,RUTA
################################################################

PRECIOS,RUTA = Precios(TARIFAS)
#print(PRECIOS[0][6])

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")
for i in range(len(TARIFAS)):
  print(RUTA[i])

#Determinar la ruta con Recursividad
def calcular_ruta(RUTA, desde, hasta):
  if desde == hasta:
    #print("Ir a :" + str(desde))
    return ""
  else:
    return str(calcular_ruta( RUTA, desde, RUTA[desde][hasta])) +  \
                ',' + \
                str(RUTA[desde][hasta] \
              )

print("\nLa ruta es:")
calcular_ruta(RUTA, 0,6)
# Out:
# PRECIOS
# [0, 5, 4, 3, 8, 8, 11]
# [9999, 0, 999, 2, 3, 8, 7]
# [9999, 9999, 0, 1, 6, 4, 7]
# [9999, 9999, 9999, 0, 5, 6, 9]
# [9999, 9999, 9999, 9999, 0, 999, 4]
# [9999, 9999, 9999, 9999, 9999, 0, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# [0, 0, 0, 0, 1, 2, 5]
# ['', 1, 1, 1, 1, 3, 4]
# ['', '', 2, 2, 3, 2, 5]
# ['', '', '', 3, 3, 3, 3]
# ['', '', '', '', 4, 4, 4]
# ['', '', '', '', '', 5, 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# ',0,2,5'

# %%
import numpy as np

puntos = np.unique(np.random.randint(0, 10000, size=1000))

# %%
print(puntos.shape)
# Out:
# (946,)

# %%
def encontrar_puntos_mas_cercanos(arr):
    min_diff = float('inf')
    puntos_mas_cercanos = None

    for i in range(len(arr)):
        for j in range(i+1, len(arr)):
            diff = abs(arr[i] - arr[j])

            if diff < min_diff:
                min_diff = diff
                puntos_mas_cercanos = (arr[i], arr[j])

    return puntos_mas_cercanos

# %%
puntos_mas_cercanos = encontrar_puntos_mas_cercanos(puntos)

# %%
print(f'Los puntos más cercanos son {puntos_mas_cercanos[0]} y {puntos_mas_cercanos[1]}')
# Out:
# Los puntos más cercanos son 31 y 32

# %% [markdown]
# Bucle i: n - 1 veces
# Bucle j: n - i - 1 veces
#
# Entonces la complejidad seria la suma de n - 1, n - 2, n -3... -> Lo que equivale a la funcion geometrica (n*(n-1)) / 2 -> O(n^2)
#
# Aplicando la estrategia divide y vencerás, podremos primero ordenar la array, lo cual usando algoritmos como quicksort o mergesort nos darian un coste de O(n log n) y luego iterar solo una vez la array O(n) en busca de la diferencia minima, ya que estaran uno al lado del otro. Por lo que quedariamos con un coste de O(n log n)

# %%
def encontrar_puntos_mas_cercanos_divide_venceras(arr):
    arr.sort()

    min_diff = float('inf')
    puntos_mas_cercanos = []

    for i in range(len(arr) - 1):
        diff = arr[i+1] - arr[i]

        if diff < min_diff:
            min_diff = diff
            puntos_mas_cercanos = (arr[i], arr[i+1])

    return puntos_mas_cercanos

# %%
puntos_mas_cercanos_2 = encontrar_puntos_mas_cercanos_divide_venceras(puntos)

# %%
print(f'Los puntos más cercanos son {puntos_mas_cercanos_2[0]} y {puntos_mas_cercanos_2[1]}')
# Out:
# Los puntos más cercanos son 31 y 32

# %% [markdown]
# Creo que no se podria mejorar mucho mas. Además para hacer la version 2D y 3D, no podremos ordenar linealmente los puntos y se necesitaran implementaciones mas avanzadas:

# %%
import math

def euclidean_distance(p1, p2):
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def closest_pair_in_strip(strip, d, best_pair):
    min_d = d
    for i in range(len(strip)):
        j = i + 1
        while j < len(strip) and (strip[j][1] - strip[i][1]) < min_d:
            dist = euclidean_distance(strip[i], strip[j])
            if dist < min_d:
                min_d = dist
                best_pair = (strip[i], strip[j])
            j += 1

    return min_d, best_pair

def closest_pair_recursive(points_sorted_x, points_sorted_y):
    if len(points_sorted_x) <= 3:
        min_d = float('inf')
        best_pair = None
        for i in range(len(points_sorted_x)):
            for j in range(i+1, len(points_sorted_x)):
                dist = euclidean_distance(points_sorted_x[i], points_sorted_x[j])
                if dist < min_d:
                    min_d = dist
                    best_pair = (points_sorted_x[i], points_sorted_x[j])
        return min_d, best_pair

    mid = len(points_sorted_x) // 2
    mid_x = points_sorted_x[mid][0]

    points_left = points_sorted_x[:mid]
    points_right = points_sorted_x[mid:]

    points_left_y = list(filter(lambda point: point[0] <= mid_x, points_sorted_y))
    points_right_y = list(filter(lambda point: point[0] > mid_x, points_sorted_y))

    d_left, pair_left = closest_pair_recursive(points_left, points_left_y)
    d_right, pair_right = closest_pair_recursive(points_right, points_right_y)

    if d_left < d_right:
        d = d_left
        best_pair = pair_left
    else:
        d = d_right
        best_pair = pair_right

    strip = [p for p in points_sorted_y if abs(p[0] - mid_x) < d]

    d_strip, pair_strip = closest_pair_in_strip(strip, d, best_pair)
    if d_strip < d:
        return d_strip, pair_strip

    return d, best_pair

def closest_pair(points):
    points_sorted_x = sorted(points, key=lambda p: p[0])
    points_sorted_y = sorted(points, key=lambda p: p[1])

    _, best_pair = closest_pair_recursive(points_sorted_x, points_sorted_y)
    return best_pair

# %%
puntos_2d = np.random.randint(0, 10000, size=(1000, 2))

# %%
print(puntos_2d[:10])
# Out:
# [[6252 6839]
#  [4524 4450]
#  [2184 2374]
#  [4103 9724]
#  [4094 5997]
#  [2195 3283]
#  [1666 9875]
#  [3693 6124]
#  [8896 1605]
#  [6920   85]]

# %%
par_mas_cercano_2d = closest_pair(puntos_2d)

# %%
print(f'Los puntos más cercanos son {par_mas_cercano_2d[0]} y {par_mas_cercano_2d[1]}')
# Out:
# Los puntos más cercanos son [3906 5039] y [3908 5044]

# %%
import math

def euclidean_distance_3d(p1, p2):
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def closest_pair_in_strip_3d(strip, d, best_pair):
    min_d = d
    # Sort the strip by y-coordinate for efficient comparison
    strip.sort(key=lambda p: p[1])
    for i in range(len(strip)):
        # Check only points within d in the y and z directions
        for j in range(i+1, len(strip)):
            if strip[j][1] - strip[i][1] < min_d:
                dist = euclidean_distance_3d(strip[i], strip[j])
                if dist < min_d:
                    min_d = dist
                    best_pair = (strip[i], strip[j])
            else:
                break
    return min_d, best_pair

def closest_pair_recursive_3d(points_sorted_x, points_sorted_y, points_sorted_z):
    if len(points_sorted_x) <= 3:
        min_d = float('inf')
        best_pair = None
        for i in range(len(points_sorted_x)):
            for j in range(i+1, len(points_sorted_x)):
                dist = euclidean_distance_3d(points_sorted_x[i], points_sorted_x[j])
                if dist < min_d:
                    min_d = dist
                    best_pair = (points_sorted_x[i], points_sorted_x[j])
        return min_d, best_pair

    mid = len(points_sorted_x) // 2
    mid_point = points_sorted_x[mid]

    points_left_x = points_sorted_x[:mid]
    points_right_x = points_sorted_x[mid:]
    points_left_y = list(filter(lambda p: p[0] <= mid_point[0], points_sorted_y))
    points_right_y = list(filter(lambda p: p[0] > mid_point[0], points_sorted_y))
    points_left_z = list(filter(lambda p: p[0] <= mid_point[0], points_sorted_z))
    points_right_z = list(filter(lambda p: p[0] > mid_point[0], points_sorted_z))

    d_left, pair_left = closest_pair_recursive_3d(points_left_x, points_left_y, points_left_z)
    d_right, pair_right = closest_pair_recursive_3d(points_right_x, points_right_y, points_right_z)

    d = min(d_left, d_right)
    best_pair = pair_left if d_left < d_right else pair_right

    # Create a strip in 3D, considering only points within d of the dividing plane
    strip = [p for p in points_sorted_y if abs(p[0] - mid_point[0]) < d]

    d_strip, pair_strip = closest_pair_in_strip_3d(strip, d, best_pair)
    if d_strip < d:
        return d_strip, pair_strip

    return d, best_pair

def closest_pair_3d(points):
    points_sorted_x = sorted(points, key=lambda p: p[0])
    points_sorted_y = sorted(points, key=lambda p: p[1])
    points_sorted_z = sorted(points, key=lambda p: p[2])

    _, best_pair = closest_pair_recursive_3d(points_sorted_x, points_sorted_y, points_sorted_z)
    return best_pair

# %%
puntos_3d = np.random.randint(0, 10000, size=(10000, 3))
par_mas_cercano_3d = closest_pair_3d(puntos_3d)
print(f'Los puntos más cercanos son {par_mas_cercano_3d[0]} y {par_mas_cercano_3d[1]}')
# Out:
# Los puntos más cercanos son [8732 4299 2978] y [8723 4302 2968]
